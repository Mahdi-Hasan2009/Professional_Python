# %% [markdown]
# 1. Connecting with SQL

# %%
import sqlite3 as Mahdi
conn = Mahdi.connect("basketball.sqlite")
print("Database connected Successfully")
# Out:
# Database connected Successfully

# %% [markdown]
# 2. All the Tables

# %%
import pandas as pd
tables = pd.read_sql("""SELECT  * FROM sqlite_master WHERE type = 'table';""", conn)
tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    Team_Attributes    Team_Attributes         2
# 1  table      Player_Salary      Player_Salary         5
# 2  table              Draft              Draft        36
# 3  table               Team               Team       314
# 4  table  Player_Attributes  Player_Attributes       315
# 5  table             Player             Player       617
#
#                                                  sql
# 0  CREATE TABLE `Team_Attributes` (`ID`, `ABBREVI...
# 1  CREATE TABLE `Player_Salary` (`slugSeason`, `n...
# 2  CREATE TABLE `Draft` (`yearDraft`, `numberPick...
# 3  CREATE TABLE `Team` (`id`, `full_name`, `abbre...
# 4  CREATE TABLE `Player_Attributes` (`ID`, `FIRST...
# 5  CREATE TABLE `Player` (`id`, `full_name`, `fir...

# %% [markdown]
# 3. THE TABLES

# %%
Player = pd.read_sql("""SELECT * FROM Player;""",  conn)

# %%
Team = pd.read_sql("""SELECT * FROM Team""", conn)

# %% [markdown]
# 4. PRINTING ALL THE TABLES

# %%
Player
# Out:
#            id            full_name first_name     last_name is_active
# 0       76001       Alaa Abdelnaby       Alaa     Abdelnaby         0
# 1       76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz         0
# 2       76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar         0
# 3          51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf         0
# 4        1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad         0
# ...       ...                  ...        ...           ...       ...
# 4496  1627790           Ante Zizic       Ante         Zizic         1
# 4497    78647             Jim Zoet        Jim          Zoet         0
# 4498    78648            Bill Zopf       Bill          Zopf         0
# 4499  1627826          Ivica Zubac      Ivica         Zubac         1
# 4500    78650           Matt Zunic       Matt         Zunic         0
#
# [4501 rows x 5 columns]

# %%
Team
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %% [markdown]
# 5. TABLES INFO

# %%
Player.info
# Out:
# <bound method DataFrame.info of            id            full_name first_name     last_name is_active
# 0       76001       Alaa Abdelnaby       Alaa     Abdelnaby         0
# 1       76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz         0
# 2       76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar         0
# 3          51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf         0
# 4        1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad         0
# ...       ...                  ...        ...           ...       ...
# 4496  1627790           Ante Zizic       Ante         Zizic         1
# 4497    78647             Jim Zoet        Jim          Zoet         0
# 4498    78648            Bill Zopf       Bill          Zopf         0
# 4499  1627826          Ivica Zubac      Ivica         Zubac         1
# 4500    78650           Matt Zunic       Matt         Zunic         0
#
# [4501 rows x 5 columns]>

# %%
Team.info
# Out:
# <bound method DataFrame.info of             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# ...

# %% [markdown]
# 6. OPERATIONS

# %%
# AVERAGE
AVG = pd.read_sql("""SELECT AVG(year_founded) AS 'AVG OF YEAR' FROM Team;""", conn)
AVG
# Out:
#    AVG OF YEAR
# 0       1969.7

# %%
# SUM
SUM = pd.read_sql("""SELECT SUM(is_active) AS 'SUM' FROM Player;""", conn)
SUM
# Out:
#    SUM
# 0  519

# %%
# ACTIVE PLAYERS
ACTIVE_PERSONALS = pd.read_sql("""SELECT * FROM Player WHERE is_active = '1';""", conn)
ACTIVE_PERSONALS
# Out:
#           id                 full_name first_name         last_name is_active
# 0     203500              Steven Adams     Steven             Adams         1
# 1    1628389               Bam Adebayo        Bam           Adebayo         1
# 2     200746         LaMarcus Aldridge   LaMarcus          Aldridge         1
# 3    1629734            Kyle Alexander       Kyle         Alexander         1
# 4    1629638  Nickeil Alexander-Walker    Nickeil  Alexander-Walker         1
# ..       ...                       ...        ...               ...       ...
# 514   201152            Thaddeus Young   Thaddeus             Young         1
# 515  1629027                Trae Young       Trae             Young         1
# 516   203469               Cody Zeller       Cody            Zeller         1
# 517  1627790                Ante Zizic       Ante             Zizic         1
# 518  1627826               Ivica Zubac      Ivica             Zubac         1
#
# [519 rows x 5 columns]

# %%
# UNIQ STATES OF TEAM
STATE = pd.read_sql("""SELECT DISTINCT state FROM Team;""", conn)
STATE
# Out:
#                    state
# 0                Atlanta
# 1          Massachusetts
# 2                   Ohio
# 3              Louisiana
# 4               Illinois
# 5                  Texas
# 6               Colorado
# 7             California
# 8                Florida
# 9              Wisconsin
# 10             Minnesota
# 11              New York
# 12               Indiana
# 13          Pennsylvania
# 14               Arizona
# 15                Oregon
# 16              Oklahoma
# 17               Ontario
# 18                  Utah
# 19             Tennessee
# 20  District of Columbia
# 21              Michigan
# 22        North Carolina
