# %%
import pandas as pd
import seaborn as sns

# %%
weather = pd.read_csv('Weather Dataset - Trial Activity DataSet.csv.csv')

# %%
weather.head()
# Out:
#           date_time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  18-05-2017 00:00         NaN                   73        63           1
# 1  18-05-2017 00:00         NaN                  251        63           1
# 2  18-05-2017 00:00         NaN                   75        56           1
# 3  18-05-2017 01:00         NaN                   98        56           1
# 4  18-05-2017 01:00         NaN                  283        56           1
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0              27                    4          4       285.15         0
# 1              27                    4          4       285.15         0
# 2               0                    1          1       285.15         0
# 3             351                    2          2       284.79         0
# 4             351                    1          1       284.79         0
#
#    snow_p_h  clouds_all weather_type      weather_description
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date_time            199 non-null    object
#  1   is_holiday           0 non-null      float64
#  2   air_pollution_index  199 non-null    int64
#  3   humidity             199 non-null    int64
#  4   wind_speed           199 non-null    int64
#  5   wind_direction       199 non-null    int64
#  6   visibility_in_miles  199 non-null    int64
#  7   dew_point            199 non-null    int64
#  8   temperature          199 non-null    float64
#  9   rain_p_h             199 non-null    int64
#  10  snow_p_h             199 non-null    int64
#  11  clouds_all           199 non-null    int64
#  12  weather_type         199 non-null    object
#  13  weather_description  199 non-null    object
# dtypes: float64(2), int64(9), object(3)
# memory usage: 21.9+ KB

# %%
sns.barplot(data=weather, x='temperature', y='wind_speed')
# Out:
# <Axes: xlabel='temperature', ylabel='wind_speed'>

# %%
sns.displot(weather['temperature'], kde=True)

# %%
sns.displot(weather['humidity'], rug=True)

# %%
sns.jointplot(data=weather, x='humidity', y='temperature')

# %%
sns.jointplot(data=weather, x='humidity', y='temperature', kind="hex")

# %%
sns.jointplot(data=weather, x='humidity', y='temperature', kind="kde")

# %%
sns.pairplot(weather[['humidity', 'temperature', 'air_pollution_index']])

# %%
sns.stripplot(data=weather, x='weather_type', y='temperature')
# Out:
# <Axes: xlabel='weather_type', ylabel='temperature'>

# %%
sns.stripplot(data=weather, x='weather_type', y='temperature', jitter=True)
# Out:
# <Axes: xlabel='weather_type', ylabel='temperature'>

# %%
sns.swarmplot(data=weather, x='humidity', y='temperature')
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
sns.boxplot(data=weather, x='humidity', y='temperature', hue='weather_type')
# Out:
# <Axes: xlabel='humidity', ylabel='temperature'>

# %%
sns.barplot(data=weather, x='humidity', y='temperature', hue='weather_type')
# Out:
# <Axes: xlabel='humidity', ylabel='temperature'>

# %%
sns.countplot(data=weather, x='weather_type')
# Out:
# <Axes: xlabel='weather_type', ylabel='count'>

# %%
sns.pointplot(data=weather, x='humidity', y='temperature', hue='weather_type')
# Out:
# <Axes: xlabel='humidity', ylabel='temperature'>

# %%
sns.lmplot(x='humidity', y='temperature', data=weather)

# %%
sns.lmplot(x="humidity", y="temperature", hue="weather_type", data=weather)
